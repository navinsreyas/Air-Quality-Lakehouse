-- %%
GRANT USE CATALOG
ON CATALOG workspace
TO `account users`;

GRANT USE SCHEMA
ON SCHEMA workspace.aq_dlt
TO `account users`;

GRANT SELECT
ON TABLE workspace.aq_dlt.gold_daily_site_summary
TO `account users`;

GRANT SELECT
ON TABLE workspace.aq_dlt.gold_regional_trend
TO `account users`;

SHOW GRANTS
ON TABLE workspace.aq_dlt.gold_daily_site_summary;

SHOW GRANTS
ON TABLE workspace.aq_dlt.gold_regional_trend;
