-- %%
SELECT COUNT(*) AS rows
FROM workspace.aq_dlt.gold_regional_trend;

SELECT
    region,
    parameter_code,
    month_start,
    COUNT(*) AS row_count
FROM workspace.aq_dlt.gold_regional_trend
GROUP BY
    region,
    parameter_code,
    month_start
HAVING COUNT(*) > 1;


SELECT *
FROM workspace.aq_dlt.gold_regional_trend
ORDER BY region, parameter_code, month_start
LIMIT 50;

SELECT COUNT(*) AS regional_rows
FROM workspace.aq_dlt.gold_regional_trend;


SELECT
    region,
    parameter_code,
    month_start,
    COUNT(*) AS row_count
FROM workspace.aq_dlt.gold_regional_trend
GROUP BY region, parameter_code, month_start
HAVING COUNT(*) > 1;
